# %%
import pandas as pd
import math

# %% [markdown]
# Dataset: https://www.kaggle.com/zhaoyingzhu/heartcsv

# %%
heart_data = pd.read_csv('Heart.csv')
heart_data
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %% [markdown]
# #### Standard error

# %%
heart_data .sem()
# Out:
# Unnamed: 0    5.033223
# Age           0.519258
# Sex           0.026846
# RestBP        1.011079
# Chol          2.974506
# Fbs           0.020463
# RestECG       0.057160
# MaxHR         1.314135
# ExAng         0.026989
# Oldpeak       0.066702
# Slope         0.035401
# Ca            0.054213
# dtype: float64

# %% [markdown]
# #### Male population with heart disease and standard error

# %%
heart_data.ChestPain.unique()
# Out:
# array(['typical', 'asymptomatic', 'nonanginal', 'nontypical'],
#       dtype=object)

# %%
heart_disease_data = heart_data.loc[heart_data['AHD']=='Yes']

# %%
male_heart_data = heart_disease_data.loc[heart_data['Sex']==1]
male_heart_data
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 8             9   63    1  asymptomatic     130   254    0        2    147
# 9            10   53    1  asymptomatic     140   203    1        2    155
# 12           13   56    1    nonanginal     130   256    1        2    142
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 293         294   63    1  asymptomatic     140   187    0        2    144
# 296         297   59    1  asymptomatic     164   176    1        2     90
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
male_heart_data.sem()
# Out:
# Unnamed: 0    8.350591
# Age           0.785342
# Sex           0.000000
# RestBP        1.612554
# Chol          4.255763
# Fbs           0.032676
# RestECG       0.092337
# MaxHR         2.161925
# ExAng         0.046855
# Oldpeak       0.114960
# Slope         0.053555
# Ca            0.093018
# dtype: float64

# %% [markdown]
# #### Confidence Interval of diff in population proportion of females and males

# %%
female_heart_data = heart_disease_data.loc[heart_data['Sex']==1]
female_heart_data
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 8             9   63    1  asymptomatic     130   254    0        2    147
# 9            10   53    1  asymptomatic     140   203    1        2    155
# 12           13   56    1    nonanginal     130   256    1        2    142
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 293         294   63    1  asymptomatic     140   187    0        2    144
# 296         297   59    1  asymptomatic     164   176    1        2     90
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
male_heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114 entries, 1 to 300
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  114 non-null    int64
#  1   Age         114 non-null    int64
#  2   Sex         114 non-null    int64
#  3   ChestPain   114 non-null    object
#  4   RestBP      114 non-null    int64
#  5   Chol        114 non-null    int64
#  6   Fbs         114 non-null    int64
#  7   RestECG     114 non-null    int64
#  8   MaxHR       114 non-null    int64
#  9   ExAng       114 non-null    int64
#  10  Oldpeak     114 non-null    float64
#  11  Slope       114 non-null    int64
#  12  Ca          113 non-null    float64
#  13  Thal        113 non-null    object
#  14  AHD         114 non-null    object
# dtypes: float64(2), int64(10), object(3)
# memory usage: 14.2+ KB

# %% [markdown]
# #### Step 1: Degrees of freedom = sample size - 1

# %%
male_dof = len(male_heart_data) - 1
male_dof
# Out:
# 113

# %% [markdown]
# #### Step 2: Subtract the confidence level from 1

# %%
(1-0.95)/2
# Out:
# 0.025000000000000022

# %% [markdown]
# #### Step 3: Look up your answers to step 1 and 2 in the t-distribution table https://www.statisticshowto.com/tables/t-distribution-table/

# %%
1.980
# Out:
# 1.98

# %% [markdown]
# #### Step 4: Divide your sample standard deviation by the square root of your sample size.

# %%
male_heart_data.std()/math.sqrt(len(male_heart_data))
# Out:
# Unnamed: 0    8.350591
# Age           0.785342
# Sex           0.000000
# RestBP        1.612554
# Chol          4.255763
# Fbs           0.032676
# RestECG       0.092337
# MaxHR         2.161925
# ExAng         0.046855
# Oldpeak       0.114960
# Slope         0.053555
# Ca            0.092609
# dtype: float64

# %% [markdown]
# #### Step 5: Multiply step 3 by step 4.

# %% [markdown]
# #### Step 6: For the lower end of the range , subtract step 5 from the sample mean

# %% [markdown]
# #### Step 7: For the upper end of the range, add step 5 to the sample mean.

# %% [markdown]
# #### CI of mean cholesterol level of female population
